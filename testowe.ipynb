# %%
# !nvidia_smi
# Out:
# /bin/dash: 1: nvidia_smi: not found

# %%
# !bash run_test.sh
# Out:
# stage0 start
# load model
# prepare test center
# start test
# 0.00% 0 / 124999
# 0.10% 128 / 124999
# 0.20% 256 / 124999
# 0.31% 384 / 124999
# 0.41% 512 / 124999
# 0.51% 640 / 124999
# 0.61% 768 / 124999
# 0.72% 896 / 124999
# 0.82% 1024 / 124999
# 0.92% 1152 / 124999
# 1.02% 1280 / 124999
# 1.13% 1408 / 124999
# 1.23% 1536 / 124999
# 1.33% 1664 / 124999
# 1.43% 1792 / 124999
# 1.54% 1920 / 124999
# 1.64% 2048 / 124999
# 1.74% 2176 / 124999
# 1.84% 2304 / 124999
# 1.95% 2432 / 124999
# 2.05% 2560 / 124999
# 2.15% 2688 / 124999
# 2.25% 2816 / 124999
# 2.36% 2944 / 124999
# 2.46% 3072 / 124999
# 2.56% 3200 / 124999
# 2.66% 3328 / 124999
# 2.76% 3456 / 124999
# 2.87% 3584 / 124999
# 2.97% 3712 / 124999
# 3.07% 3840 / 124999
# 3.17% 3968 / 124999
# 3.28% 4096 / 124999
# 3.38% 4224 / 124999
# 3.48% 4352 / 124999
# 3.58% 4480 / 124999
# 3.69% 4608 / 124999
# 3.79% 4736 / 124999
# 3.89% 4864 / 124999
# 3.99% 4992 / 124999
# 4.10% 5120 / 124999
# 4.20% 5248 / 124999
# 4.30% 5376 / 124999
# ...

# %%
 mkdir nana1; ln -s /media/kuka2/Dane/vision_based_method_data/HandAugment_method/test/Task1 nana1/Hnna

# %%
cd HANDS19_Challenge
# Out:
# /HandAugment_method/HandAugment/dataset/HANDS19_Challenge

# %%
# !apt-get install zip --yes
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
# !bash run_test_part2.sh
# Out:
# stage1 start
# usage: test_hands19task1.py [-h] [-m MODEL_PATH] [-o OUTPUT_RESULT_PATH]
#                             [-i INPUT_TEST_IMG_FOLDER] [--gpu_id GPU_ID]
#                             [--batch_size BATCH_SIZE] [--verbose]
# test_hands19task1.py: error: argument -o/--output_result_path: expected one argument
# usage: test_hands19task1.py [-h] [-m MODEL_PATH] [-o OUTPUT_RESULT_PATH]
#                             [-i INPUT_TEST_IMG_FOLDER] [--gpu_id GPU_ID]
#                             [--batch_size BATCH_SIZE] [--verbose]
#
# get result.txt.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -m MODEL_PATH, --model_path MODEL_PATH
#                         Input model
#   -o OUTPUT_RESULT_PATH, --output_result_path OUTPUT_RESULT_PATH
#                         Output path of result.txt
#   -i INPUT_TEST_IMG_FOLDER, --input_test_img_folder INPUT_TEST_IMG_FOLDER
#                         test set image folder
# ...

# %%
# !zip -q result.txt.zip result.txt
# Out:
# zip error: Nothing to do! (result.txt.zip)
